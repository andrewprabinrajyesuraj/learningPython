# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewprabinrajyesuraj/learningPython/blob/featurebranch1/learningColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("heloo")
# Out:
# heloo

# %%
print("kkkk")
print("no")
# Out:
# kkkk
# no
